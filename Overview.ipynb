# %% [markdown]
# end to end on a full project
#
# Day1:
# - pick a dataset- 1hr
# - project planning (trello)- 1hr
#     - target
#     - goals
#     - deliverables
# - data acquire and prep - 2hours
# - explore- 2.5 hours
#
# Day2:(MVP by End of Day)
# - summarize findings from explore - 1hr
# - Model- 2hrs
# - version 2- changes or new features 2.5hours
# - prepare to deliver- 1hr
#
# Day3:
# - further your MVP
#     - improve on pipeline
# - project summary/ write up (README)
#
# Day4:
# - Peer Review

# %%
import pandas as pd

# %% [markdown]
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# # Take a look at these datasets. Pick one!

# %% [markdown]
# ### Recidivism in Iowa

# %%
df = pd.read_csv('Recidivism_in_Iowa.csv')

# %%
df.head()
# Out:
#    Fiscal Year Released  Recidivism Reporting Year      Race - Ethnicity  \
# 0                  2010                       2013  White - Non-Hispanic
# 1                  2010                       2013  White - Non-Hispanic
# 2                  2010                       2013  White - Non-Hispanic
# 3                  2010                       2013  White - Non-Hispanic
# 4                  2010                       2013  Black - Non-Hispanic
#
#   Age At Release  Convicting Offense Classification Convicting Offense Type  \
# 0        Under 25                          D Felony                 Violent
# 1    55 and Older                          D Felony            Public Order
# 2           25-34                          D Felony                Property
# 3    55 and Older                          C Felony                    Drug
# 4           25-34                          D Felony                    Drug
#
# ...

# %% [markdown]
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# ### Drug Overdose Deaths
# https://www.kaggle.com/ruchi798/drug-overdose-deaths

# %%
od_df= pd.read_csv('drug_deaths.csv')

# %%
od_df.head()
#would need to drop unnamed column
#set date as inde
#already has dummies
# Out:
#    Unnamed: 0       ID                    Date  DateType   Age     Sex  \
# 0           0  14-0273  06/28/2014 12:00:00 AM       1.0   NaN     NaN
# 1           1  13-0102  03/21/2013 12:00:00 AM       0.0  48.0    Male
# 2           2  16-0165  03/13/2016 12:00:00 AM       0.0  30.0  Female
# 3           3  16-0208  03/31/2016 12:00:00 AM       0.0  23.0    Male
# 4           4  13-0052  02/13/2013 12:00:00 AM       0.0  22.0    Male
#
#            Race ResidenceCity ResidenceCounty ResidenceState  ... Tramad  \
# 0           NaN           NaN             NaN            NaN  ...      0
# 1         Black       NORWALK             NaN            NaN  ...      0
# 2         White    SANDY HOOK       FAIRFIELD             CT  ...      0
# 3         White           RYE     WESTCHESTER             NY  ...      0
# 4  Asian, Other      FLUSHING          QUEENS            NaN  ...      0
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %%
od_df.MannerofDeath.unique()
# need to clean accident to be uniform
# Out:
# array(['Accident', 'accident', nan, 'Pending', 'ACCIDENT', 'Natural'],
#       dtype=object)

# %% [markdown]
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# ### Crime/Incarceration rates by state

# %%
crime_df= pd.read_csv('crime_and_incarceration_by_state.csv')

# %%
crime_df.head()
# Out:
#   jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 0      FEDERAL           False  2001          149852                    NaN
# 1      ALABAMA           False  2001           24741                  False
# 2       ALASKA            True  2001            4570                  False
# 3      ARIZONA           False  2001           27710                  False
# 4     ARKANSAS           False  2001           11489                  False
#
#   crimes_estimated  state_population  violent_crime_total  \
# 0              NaN               NaN                  NaN
# 1            False         4468912.0              19582.0
# 2            False          633630.0               3735.0
# 3            False         5306966.0              28675.0
# 4            False         2694698.0              12190.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 0                  NaN          NaN           NaN      NaN          NaN
# ...
